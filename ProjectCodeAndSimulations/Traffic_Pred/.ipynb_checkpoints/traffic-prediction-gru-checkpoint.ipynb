# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import tensorflow
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import MinMaxScaler
from tensorflow import keras
from keras import callbacks
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading The Dataset

# %% [markdown]
# Loading the dataset and exploring the initial values

# %%
df = pd.read_csv("Data/traffic.csv")
df.head()
# Out:
#               DateTime  Junction  Vehicles           ID
# 0  2015-11-01 00:00:00         1        15  20151101001
# 1  2015-11-01 01:00:00         1        13  20151101011
# 2  2015-11-01 02:00:00         1        10  20151101021
# 3  2015-11-01 03:00:00         1         7  20151101031
# 4  2015-11-01 04:00:00         1         9  20151101041

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48120 entries, 0 to 48119
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  48120 non-null  object
#  1   Junction  48120 non-null  int64
#  2   Vehicles  48120 non-null  int64
#  3   ID        48120 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# **Data Detail**
#
# The dataset can be collected by a combination of Arduino , ESP8266 and open cv by placing them at various junctions to aquire 4 features.
#
# 1) DateTime
# 2) Junctions
# 3) No of Vehicles
# 4) Tag ID
#
# Data was aquired at various time leading to a sparse data for some junctions.

# %% [markdown]
# # Converting Data into Datetime and Data cleaning

# %%
df["DateTime"]= pd.to_datetime(df["DateTime"])
df = df.drop(["ID"], axis=1) #dropping IDs
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48120 entries, 0 to 48119
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DateTime  48120 non-null  datetime64[ns]
#  1   Junction  48120 non-null  int64
#  2   Vehicles  48120 non-null  int64
# dtypes: datetime64[ns](1), int64(2)
# memory usage: 1.1 MB

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# We will plot the Traffic count at various junction to explore the dataset.

# %%
df=df.copy() 
colors = [ "#FFD4DB","#800080","#FF0000","#dfe2b6"]
plt.figure(figsize=(20,20))
Time_series=sns.lineplot(x=df['DateTime'],y="Vehicles",data=df, hue="Junction", palette=colors)
Time_series.set_title("Annual junction Traffic")
Time_series.set_ylabel("Vehicles count")
Time_series.set_xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# **We can deduce from the above plot:**
#
# * The first junction has an increase in vehicle count
# * The data for the fourth junction is collected after 2017 jan

# %% [markdown]
# At this step, we are creating new features from DateTime df.
# Namely:
#
# * Days of week
# * Hour

# %% [markdown]
# # Exploring new features

# %% [markdown]
# Exploring data set based on hourly and daily traffic at various junctions

# %%
df["Hour"]= df['DateTime'].dt.hour
df["Day"]= df.DateTime.dt.strftime("%A")
df.head()
# Out:
#              DateTime  Junction  Vehicles  Hour     Day
# 0 2015-11-01 00:00:00         1        15     0  Sunday
# 1 2015-11-01 01:00:00         1        13     1  Sunday
# 2 2015-11-01 02:00:00         1        10     2  Sunday
# 3 2015-11-01 03:00:00         1         7     3  Sunday
# 4 2015-11-01 04:00:00         1         9     4  Sunday

# %%
new_features = [ "Hour", "Day"]

for i in new_features:
    plt.figure(figsize=(10,5))
    ax=sns.lineplot(x=df[i],y="Vehicles",data=df, hue="Junction", palette=['red','blue','green','black'] )
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# **From the above plot following things can be concluded:**
#
# * There has been increase in traffic in all junctions except the fourth
#
# * Daily, we can see peaks during morning and evening times and a decline during night hours.

# %%
#Pivoting data fron junction 
df_J = df.pivot(columns="Junction", index="DateTime")
df_J.describe()
# Out:
#               Vehicles                                                   Hour  \
# Junction             1             2             3            4             1
# count     14592.000000  14592.000000  14592.000000  4344.000000  14592.000000
# mean         45.052906     14.253221     13.694010     7.251611     11.500000
# std          23.008345      7.401307     10.436005     3.521455      6.922424
# min           5.000000      1.000000      1.000000     1.000000      0.000000
# 25%          27.000000      9.000000      7.000000     5.000000      5.750000
# 50%          40.000000     13.000000     11.000000     7.000000     11.500000
# 75%          59.000000     17.000000     18.000000     9.000000     17.250000
# max         156.000000     48.000000    180.000000    36.000000     23.000000
#
#
# Junction             2             3            4
# count     14592.000000  14592.000000  4344.000000
# mean         11.500000     11.500000    11.500000
# std           6.922424      6.922424     6.922983
# min           0.000000      0.000000     0.000000
# 25%           5.750000      5.750000     5.750000
# 50%          11.500000     11.500000    11.500000
# 75%          17.250000     17.250000    17.250000
# max          23.000000     23.000000    23.000000

# %%
#Creating new sets
df_1 = df_J[[('Vehicles', 1)]]
df_2 = df_J[[('Vehicles', 2)]]
df_3 = df_J[[('Vehicles', 3)]]
df_4 = df_J[[('Vehicles', 4)]]
df_4 = df_4.dropna() #Junction 4 has limited data only for a few months

#Dropping level one in dfs's index as it is a multi index data frame
list_dfs = [df_1, df_2, df_3, df_4]
for i in list_dfs:
    i.columns= i.columns.droplevel(level=1)

# %% [markdown]
# A time series is stationary if it does not have a trend or seasonality. However, in the EDA, we saw a weekly seasonality and an upwards trend over the years. In the above plot, it is again established that Junctions one and two have an upward trend. If we limit the span we will be able to further see the weekly seasonality. I will be spairing that step at this point and moving on with the respective transforms on datasets.
#
# **Steps for Transforming:**
# * Normalizing
# * Differencing

# %%
# Normalize Function
def Normalize(df,col):
    average = df[col].mean()
    stdev = df[col].std()
    df_normalized = (df[col] - average) / stdev
    df_normalized = df_normalized.to_frame()
    return df_normalized, average, stdev

# Differencing Function
def Difference(df,col, interval):
    diff = []
    for i in range(interval, len(df)):
        value = df[col][i] - df[col][i - interval]
        diff.append(value)
    return diff

# %% [markdown]
# In accordance with the above observations, Differencing to eliminate the seasonality should be performed as follows:
# * For Junction one, I will be taking a difference of weekly values.
# * For junction two, The difference of consecutive days is a better choice
# * For Junctions three and four, the difference of the hourly values will serve the purpose.

# %%
#Normalizing and Differencing to make the series stationary 
df_N1, av_J1, std_J1 = Normalize(df_1, "Vehicles")
Diff_1 = Difference(df_N1, col="Vehicles", interval=(24*7)) #taking a week's diffrence
df_N1 = df_N1[24*7:]
df_N1.columns = ["Norm"]
df_N1["Diff"]= Diff_1

df_N2, av_J2, std_J2 = Normalize(df_2, "Vehicles")
Diff_2 = Difference(df_N2, col="Vehicles", interval=(24)) #taking a day's diffrence
df_N2 = df_N2[24:]
df_N2.columns = ["Norm"]
df_N2["Diff"]= Diff_2

df_N3, av_J3, std_J3 = Normalize(df_3, "Vehicles")
Diff_3 = Difference(df_N3, col="Vehicles", interval=1) #taking an hour's diffrence
df_N3 = df_N3[1:]
df_N3.columns = ["Norm"]
df_N3["Diff"]= Diff_3

df_N4, av_J4, std_J4 = Normalize(df_4, "Vehicles")
Diff_4 = Difference(df_N4, col="Vehicles", interval=1) #taking an hour's diffrence
df_N4 = df_N4[1:]
df_N4.columns = ["Norm"]
df_N4["Diff"]= Diff_4

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# **Now that the data is stationary,  preprocessing the data for the neural net by:**
#
# * Splitting data into test train, reshaping for NN

# %%
#Differencing created some NA values as we took a weeks data into consideration while difrencing
df_J1 = df_N1["Diff"].dropna()
df_J1 = df_J1.to_frame()

df_J2 = df_N2["Diff"].dropna()
df_J2 = df_J2.to_frame()

df_J3 = df_N3["Diff"].dropna()
df_J3 = df_J3.to_frame()

df_J4 = df_N4["Diff"].dropna()
df_J4 = df_J4.to_frame()

#Splitting the dataset
def Split_data(df):
    training_size = int(len(df)*0.90)
    data_len = len(df)
    train, test = df[0:training_size],df[training_size:data_len] 
    train, test = train.values.reshape(-1, 1), test.values.reshape(-1, 1)
    return train, test
#Splitting the training and test datasets 
J1_train, J1_test = Split_data(df_J1)
J2_train, J2_test = Split_data(df_J2)
J3_train, J3_test = Split_data(df_J3)
J4_train, J4_test = Split_data(df_J4)

#Target and Feature
def TnF(df):
    end_len = len(df)
    X = []
    y = []
    steps = 32
    for i in range(steps, end_len):
        X.append(df[i - steps:i, 0])
        y.append(df[i, 0])
    X, y = np.array(X), np.array(y)
    return X ,y

#fixing the shape of X_test and X_train
def FeatureFixShape(train, test):
    train = np.reshape(train, (train.shape[0], train.shape[1], 1))
    test = np.reshape(test, (test.shape[0],test.shape[1],1))
    return train, test

#Assigning features and target 
X_trainJ1, y_trainJ1 = TnF(J1_train)
X_testJ1, y_testJ1 = TnF(J1_test)
X_trainJ1, X_testJ1 = FeatureFixShape(X_trainJ1, X_testJ1)

X_trainJ2, y_trainJ2 = TnF(J2_train)
X_testJ2, y_testJ2 = TnF(J2_test)
X_trainJ2, X_testJ2 = FeatureFixShape(X_trainJ2, X_testJ2)

X_trainJ3, y_trainJ3 = TnF(J3_train)
X_testJ3, y_testJ3 = TnF(J3_test)
X_trainJ3, X_testJ3 = FeatureFixShape(X_trainJ3, X_testJ3)

X_trainJ4, y_trainJ4 = TnF(J4_train)
X_testJ4, y_testJ4 = TnF(J4_test)
X_trainJ4, X_testJ4 = FeatureFixShape(X_trainJ4, X_testJ4)

# %% [markdown]
# # Model building

# %%
def GRU_model(X_Train, y_Train, X_Test):
    early_stopping = callbacks.EarlyStopping(min_delta=0.001,patience=10, restore_best_weights=True) #for regularization
    
    model = Sequential()
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=150, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(GRU(units=50, return_sequences=True, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
 
    model.add(GRU(units=50, input_shape=(X_Train.shape[1],1), activation='tanh'))
    model.add(Dropout(0.2))
    model.add(Dense(units=1))
   
    model.compile(optimizer=SGD(decay=1e-7, momentum=0.9),loss='mean_squared_error')
    model.fit(X_Train,y_Train, epochs=50, batch_size=150,callbacks=[early_stopping])
    pred_GRU= model.predict(X_Test)
    return pred_GRU

#Root mean square error 
def RMSE_Value(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))
    return rmse

#To plot the comparitive plot of targets and predictions
def PredictionsPlot(test,predicted,m):
    plt.figure(figsize=(12,5))
    plt.plot(test, color=colors[m],label="True Value",alpha=0.5 )
    plt.plot(predicted, color="#627D78",label="Predicted Values")
    plt.title("Prediction Vs True values")
    plt.xlabel("DateTime")
    plt.ylabel("Number of Vehicles")
    plt.legend()
    plt.show()

# %% [markdown]
# **Fitting the first junction and plotting the predictions and testset**

# %%
#Predictions For First Junction
PredJ1 = GRU_model(X_trainJ1,y_trainJ1,X_testJ1)
# Out:
# Epoch 1/50
# 86/87 [============================>.] - ETA: 0s - loss: 0.0810WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 7s 19ms/step - loss: 0.0809
# Epoch 2/50
# 86/87 [============================>.] - ETA: 0s - loss: 0.0658WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 17ms/step - loss: 0.0658
# Epoch 3/50
# 85/87 [============================>.] - ETA: 0s - loss: 0.0642WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 17ms/step - loss: 0.0638
# Epoch 4/50
# 86/87 [============================>.] - ETA: 0s - loss: 0.0629WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 2s 17ms/step - loss: 0.0629
# Epoch 5/50
# 84/87 [===========================>..] - ETA: 0s - loss: 0.0614WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 17ms/step - loss: 0.0613
# Epoch 6/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0602WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0602
# Epoch 7/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0596WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0596
# Epoch 8/50
# 86/87 [============================>.] - ETA: 0s - loss: 0.0579WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0579
# Epoch 9/50
# 85/87 [============================>.] - ETA: 0s - loss: 0.0569WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0572
# Epoch 10/50
# 86/87 [============================>.] - ETA: 0s - loss: 0.0569WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0568
# Epoch 11/50
# 84/87 [===========================>..] - ETA: 0s - loss: 0.0554WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0557
# Epoch 12/50
# 86/87 [============================>.] - ETA: 0s - loss: 0.0560WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0559
# Epoch 13/50
# 84/87 [===========================>..] - ETA: 0s - loss: 0.0553WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0552
# Epoch 14/50
# 84/87 [===========================>..] - ETA: 0s - loss: 0.0538WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0539
# Epoch 15/50
# 85/87 [============================>.] - ETA: 0s - loss: 0.0539WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0541
# Epoch 16/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0537WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0537
# Epoch 17/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0537WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0537
# Epoch 18/50
# 85/87 [============================>.] - ETA: 0s - loss: 0.0529WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0528
# Epoch 19/50
# 86/87 [============================>.] - ETA: 0s - loss: 0.0525WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0525
# Epoch 20/50
# 86/87 [============================>.] - ETA: 0s - loss: 0.0515WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0516
# Epoch 21/50
# 85/87 [============================>.] - ETA: 0s - loss: 0.0518WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0515
# Epoch 22/50
# 86/87 [============================>.] - ETA: 0s - loss: 0.0511WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0511
# Epoch 23/50
# 85/87 [============================>.] - ETA: 0s - loss: 0.0505WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0505
# Epoch 24/50
# 84/87 [===========================>..] - ETA: 0s - loss: 0.0507WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0507
# Epoch 25/50
# 84/87 [===========================>..] - ETA: 0s - loss: 0.0508WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0505
# Epoch 26/50
# 85/87 [============================>.] - ETA: 0s - loss: 0.0497WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0498
# Epoch 27/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0499WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0499
# Epoch 28/50
# 86/87 [============================>.] - ETA: 0s - loss: 0.0499WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0499
# Epoch 29/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0496WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0496
# Epoch 30/50
# 86/87 [============================>.] - ETA: 0s - loss: 0.0496WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0496
# Epoch 31/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0497WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0497
# Epoch 32/50
# 84/87 [===========================>..] - ETA: 0s - loss: 0.0488WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0492
# Epoch 33/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0492WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0492
# Epoch 34/50
# 85/87 [============================>.] - ETA: 0s - loss: 0.0495WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0494
# Epoch 35/50
# 85/87 [============================>.] - ETA: 0s - loss: 0.0493WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0491
# Epoch 36/50
# 84/87 [===========================>..] - ETA: 0s - loss: 0.0487WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0490
# Epoch 37/50
# 84/87 [===========================>..] - ETA: 0s - loss: 0.0486WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0489
# Epoch 38/50
# 86/87 [============================>.] - ETA: 0s - loss: 0.0486WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0486
# Epoch 39/50
# 86/87 [============================>.] - ETA: 0s - loss: 0.0487WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0486
# Epoch 40/50
# 85/87 [============================>.] - ETA: 0s - loss: 0.0484WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0483
# Epoch 41/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0481WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0481
# Epoch 42/50
# 85/87 [============================>.] - ETA: 0s - loss: 0.0478WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0481
# Epoch 43/50
# 86/87 [============================>.] - ETA: 0s - loss: 0.0486WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0486
# Epoch 44/50
# 85/87 [============================>.] - ETA: 0s - loss: 0.0478WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0479
# Epoch 45/50
# 84/87 [===========================>..] - ETA: 0s - loss: 0.0476WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0477
# Epoch 46/50
# 87/87 [==============================] - ETA: 0s - loss: 0.0482WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 16ms/step - loss: 0.0482
# Epoch 47/50
# 84/87 [===========================>..] - ETA: 0s - loss: 0.0479WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0478
# Epoch 48/50
# 86/87 [============================>.] - ETA: 0s - loss: 0.0479WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0479
# Epoch 49/50
# 85/87 [============================>.] - ETA: 0s - loss: 0.0477WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0477
# Epoch 50/50
# 84/87 [===========================>..] - ETA: 0s - loss: 0.0480WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 87/87 [==============================] - 1s 15ms/step - loss: 0.0480
# 45/45 [==============================] - 1s 5ms/step

# %% [markdown]
# We can Plot comparision of the actual value and true values for some of the junctions

# %%
RMSE_J1=RMSE_Value(y_testJ1,PredJ1)
PredictionsPlot(y_testJ1,PredJ1,0)
# Out:
# The root mean squared error is 0.24613658986074624.

# %% [markdown]
# **Fitting the third junction and plotting the predictions and testset**

# %%
#Predictions For Third Junction
PredJ3 = GRU_model(X_trainJ3,y_trainJ3,X_testJ3)
# Out:
# Epoch 1/50
# 86/88 [============================>.] - ETA: 0s - loss: 0.3006WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 6s 17ms/step - loss: 0.3024
# Epoch 2/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2939WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2949
# Epoch 3/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2923WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2923
# Epoch 4/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2904WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2902
# Epoch 5/50
# 86/88 [============================>.] - ETA: 0s - loss: 0.2952WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2931
# Epoch 6/50
# 86/88 [============================>.] - ETA: 0s - loss: 0.2924WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2895
# Epoch 7/50
# 85/88 [===========================>..] - ETA: 0s - loss: 0.2897WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2877
# Epoch 8/50
# 86/88 [============================>.] - ETA: 0s - loss: 0.2892WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2875
# Epoch 9/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2882WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 16ms/step - loss: 0.2878
# Epoch 10/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2899WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2899
# Epoch 11/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2869WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2869
# Epoch 12/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2864WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2864
# Epoch 13/50
# 85/88 [===========================>..] - ETA: 0s - loss: 0.2897WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2853
# Epoch 14/50
# 86/88 [============================>.] - ETA: 0s - loss: 0.2824WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2818
# Epoch 15/50
# 85/88 [===========================>..] - ETA: 0s - loss: 0.2826WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2815
# Epoch 16/50
# 86/88 [============================>.] - ETA: 0s - loss: 0.2782WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2819
# Epoch 17/50
# 85/88 [===========================>..] - ETA: 0s - loss: 0.2801WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2788
# Epoch 18/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2781WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2781
# Epoch 19/50
# 86/88 [============================>.] - ETA: 0s - loss: 0.2754WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2757
# Epoch 20/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2784WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2789
# Epoch 21/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2761WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2761
# Epoch 22/50
# 85/88 [===========================>..] - ETA: 0s - loss: 0.2748WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2755
# Epoch 23/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2766WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2766
# Epoch 24/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2725WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2730
# Epoch 25/50
# 84/88 [===========================>..] - ETA: 0s - loss: 0.2770WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2749
# Epoch 26/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2764WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2764
# Epoch 27/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2727WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2727
# Epoch 28/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2726WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2735
# Epoch 29/50
# 86/88 [============================>.] - ETA: 0s - loss: 0.2775WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2754
# Epoch 30/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2722WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2722
# Epoch 31/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2690WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 16ms/step - loss: 0.2690
# Epoch 32/50
# 86/88 [============================>.] - ETA: 0s - loss: 0.2709WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2696
# Epoch 33/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2708WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2708
# Epoch 34/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2694WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2694
# Epoch 35/50
# 86/88 [============================>.] - ETA: 0s - loss: 0.2718WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2721
# Epoch 36/50
# 86/88 [============================>.] - ETA: 0s - loss: 0.2680WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2667
# Epoch 37/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2695WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2695
# Epoch 38/50
# 85/88 [===========================>..] - ETA: 0s - loss: 0.2722WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2704
# Epoch 39/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2673WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2673
# Epoch 40/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2673WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2673
# Epoch 41/50
# 86/88 [============================>.] - ETA: 0s - loss: 0.2697WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 16ms/step - loss: 0.2681
# Epoch 42/50
# 85/88 [===========================>..] - ETA: 0s - loss: 0.2676WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2676
# Epoch 43/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2676WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2674
# Epoch 44/50
# 85/88 [===========================>..] - ETA: 0s - loss: 0.2624WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2660
# Epoch 45/50
# 86/88 [============================>.] - ETA: 0s - loss: 0.2677WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 16ms/step - loss: 0.2654
# Epoch 46/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2654WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2648
# Epoch 47/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2659WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 16ms/step - loss: 0.2659
# Epoch 48/50
# 85/88 [===========================>..] - ETA: 0s - loss: 0.2578WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2638
# Epoch 49/50
# 87/88 [============================>.] - ETA: 0s - loss: 0.2662WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2659
# Epoch 50/50
# 88/88 [==============================] - ETA: 0s - loss: 0.2658WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 88/88 [==============================] - 1s 15ms/step - loss: 0.2658
# 45/45 [==============================] - 1s 6ms/step

# %%
#Results for J3
RMSE_J3=RMSE_Value(y_testJ3,PredJ3)
PredictionsPlot(y_testJ3,PredJ3,2)
# Out:
# The root mean squared error is 0.6084011090802133.

# %% [markdown]
# **Prediction Error at various traffic junctions **

# %%
Junctions = ["Junction1", "Junction3"]
RMSE = [RMSE_J1, RMSE_J3]
list_of_tuples = list(zip(Junctions, RMSE))
Results = pd.DataFrame(list_of_tuples, columns=["Junction", "RMSE"])
Results.style.background_gradient(cmap="Pastel1")
# Out:
# <style type="text/css">
# #T_2c230_row0_col1 {
#   background-color: #fbb4ae;
#   color: #000000;
# }
# #T_2c230_row1_col1 {
#   background-color: #f2f2f2;
#   color: #000000;
# }
# </style>
# <table id="T_2c230">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c230_level0_col0" class="col_heading level0 col0" >Junction</th>
#       <th id="T_2c230_level0_col1" class="col_heading level0 col1" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c230_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2c230_row0_col0" class="data row0 col0" >Junction1</td>
#       <td id="T_2c230_row0_col1" class="data row0 col1" >0.246137</td>
#     </tr>
#     <tr>
#       <th id="T_2c230_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2c230_row1_col0" class="data row1 col0" >Junction3</td>
#       <td id="T_2c230_row1_col1" class="data row1 col1" >0.608401</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **Summary**
#
# *In this sample code we used a GRU Neural network to predict the traffic on four junctions.
# We used normalizing and differencing to transform it to a stationary timerseries. We used RMSE as our evaluation model.
